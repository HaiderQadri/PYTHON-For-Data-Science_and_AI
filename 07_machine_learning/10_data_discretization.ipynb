# %% [markdown]
# ## Discretization (converting continuous data into category bins)

# %%
# import liberaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import KBinsDiscretizer

# %%
# load the dataset
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# check for missing values
df.isnull().sum().sort_values(ascending = False)
# Out:
# deck           688
# age            177
# embarked         2
# embark_town      2
# survived         0
# pclass           0
# sex              0
# sibsp            0
# parch            0
# fare             0
# class            0
# who              0
# adult_male       0
# alive            0
# alone            0
# dtype: int64

# %%
# first we need to impuet the missing values 
df['age'] = df['age'].fillna(df['age'].median())

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  bined_age
# 0    man        True  NaN  Southampton    no  False        0.0
# 1  woman       False    C    Cherbourg   yes  False        1.0
# 2  woman       False  NaN  Southampton   yes   True        0.0
# 3  woman       False    C  Southampton   yes  False        1.0
# 4    man        True  NaN  Southampton    no   True        1.0

# %%
sns.histplot(df['age'])
plt.show()

# %%
# calling discretizatior
age_discretizer = KBinsDiscretizer(n_bins = 3 , encode = 'ordinal', strategy = 'uniform')

# %%
# fitting data in to discretizer
df['bined_age'] = age_discretizer.fit_transform(df[['age']])
df.head()
# Out:
# C:\Users\Ali\miniconda3\envs\myenv\Lib\site-packages\sklearn\preprocessing\_discretization.py:248: FutureWarning: In version 1.5 onwards, subsample=200_000 will be used by default. Set subsample explicitly to silence this warning in the mean time. Set subsample=None to disable subsampling explicitly.
#   warnings.warn(
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  bined_age
# 0    man        True  NaN  Southampton    no  False        0.0
# 1  woman       False    C    Cherbourg   yes  False        1.0
# ...

# %%
# how do we know that bining is done let's see graph
sns.histplot(df, x = 'age', hue = 'bined_age')
plt.show()

# %% [markdown]
# ## Use pandas method for manual binning

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# check for missing values
df['age'].isnull().sum()
# Out:
# 177

# %%
# impute missing values
df['age'] = df['age'].fillna(df['age'].median())
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# again, check for missing values
df['age'].isnull().sum()
# Out:
# 0

# %%
df['bined_age'] = pd.cut(df['age'], bins = [0, 10, 18, 30, 50, 80], labels = ['child', 'teenager', 'young adults', 'adults', 'elder'])
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone     bined_age
# 0    man        True  NaN  Southampton    no  False  young adults
# 1  woman       False    C    Cherbourg   yes  False        adults
# 2  woman       False  NaN  Southampton   yes   True  young adults
# 3  woman       False    C  Southampton   yes  False        adults
# 4    man        True  NaN  Southampton    no   True        adults

# %%
sns.histplot(df, x = 'age', hue = 'bined_age')
plt.show()
